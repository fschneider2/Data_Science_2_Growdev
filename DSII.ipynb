# %%
import pandas as pd
import numpy as np

# %%
livros = pd.read_csv('livros.csv')
livros_classicos = pd.read_csv('livros_classicos.csv')
livros_genero = pd.read_csv('livros_genero.csv')

# %% [markdown]
# 1- Faça a concatenação das bases de dados e encontre qual o gênero de livro correspondente a cada livro.

# %%
livros_concatenado = pd.concat([livros,livros_genero], axis = 1)
livros_concatenado[['nome','genero']]
# Out:
#         nome    genero
# 0    livro 1     Drama
# 1    livro 2  Aventura
# 2    livro 3     Drama
# 3    livro 4   Romance
# 4    livro 5   Romance
# 5    livro 6  Aventura
# 6    livro 7     Drama
# 7    livro 8  Aventura
# 8    livro 9   Romance
# 9   livro 10  Aventura
# 10       NaN   Romance

# %% [markdown]
# 2 - Faça a concatenação das bases de dados de livros e livros_genero e encontre qual os gêneros e os autores que não possuem um livro correspondente.

# %%
livros_concatenado_autor = pd.concat([livros,livros_genero], axis = 1)
registros = livros_concatenado_autor[livros_concatenado_autor['nome'].isnull()]
registros
# Out:
#    nome  paginas   genero  autor
# 10  NaN      NaN  Romance  Pedro

# %% [markdown]
# 3 - Faça a junção das bases de livros e livros clássicos.

# %%
livros_concatenado = pd.concat([livros,livros_classicos])
livros_concatenado
# Out:
#        nome  paginas    autor
# 0   livro 1    257.0      NaN
# 1   livro 2    106.0      NaN
# 2   livro 3    150.0      NaN
# 3   livro 4    175.0      NaN
# 4   livro 5    321.0      NaN
# 5   livro 6    159.0      NaN
# 6   livro 7    980.0      NaN
# 7   livro 8    235.0      NaN
# 8   livro 9    745.0      NaN
# 9  livro 10    126.0      NaN
# 0   livro 1      NaN    Jorge
# 1   livro 2      NaN   Santos
# 2   livro 3      NaN  Leandro
# 3   livro 4      NaN    Clara
# 4   livro 5      NaN   Flavia
# 5   livro 6      NaN  Leandro
# 6   livro 7      NaN   Santos
# 7   livro 8      NaN   Marcia
# 8   livro 9      NaN   Marcia
# 9  livro 10      NaN    Clara

# %% [markdown]
# 4 - Faça a junção das bases de livros e livros clássicos apenas com os elementos em comum entre ambos e remova os índices dos antigos dataframes.

# %%
livros_concatenado = pd.concat([livros,livros_classicos], axis = 0, join='inner', ignore_index=True)
livros_concatenado
# Out:
#         nome
# 0    livro 1
# 1    livro 2
# 2    livro 3
# 3    livro 4
# 4    livro 5
# 5    livro 6
# 6    livro 7
# 7    livro 8
# 8    livro 9
# 9   livro 10
# 10   livro 1
# 11   livro 2
# 12   livro 3
# 13   livro 4
# 14   livro 5
# 15   livro 6
# 16   livro 7
# 17   livro 8
# 18   livro 9
# 19  livro 10

# %% [markdown]
# ### 5) Faça a junção das bases de livros e livros clássicos apenas com os elementos comuns entre ambos, e adicione chaves para o dataframe de livros e de livros clássicos.

# %%
livros_concatenado = pd.concat([livros,livros_classicos], axis = 0, keys=['livros',
'livros_classicos'], join='inner')
livros_concatenado
# Out:
#                         nome
# livros           0   livro 1
#                  1   livro 2
#                  2   livro 3
#                  3   livro 4
#                  4   livro 5
#                  5   livro 6
#                  6   livro 7
#                  7   livro 8
#                  8   livro 9
#                  9  livro 10
# livros_classicos 0   livro 1
#                  1   livro 2
#                  2   livro 3
#                  3   livro 4
#                  4   livro 5
#                  5   livro 6
#                  6   livro 7
#                  7   livro 8
#                  8   livro 9
#                  9  livro 10

# %% [markdown]
# ### 6) Faça a junção das bases de livros e livros clássicos apenas com os elementos comuns entre ambos, e adicione chaves para o dataframe de livros e de livros clássicos, além de nomes para os índices.

# %%
livros_concatenado = pd.concat([livros,livros_classicos], axis = 0, keys=['livros',
'livros_classicos'], join='inner', names=['dataframe','index'])
livros_concatenado
# Out:
#                             nome
# dataframe        index
# livros           0       livro 1
#                  1       livro 2
#                  2       livro 3
#                  3       livro 4
#                  4       livro 5
#                  5       livro 6
#                  6       livro 7
#                  7       livro 8
#                  8       livro 9
#                  9      livro 10
# livros_classicos 0       livro 1
#                  1       livro 2
#                  2       livro 3
#                  3       livro 4
#                  4       livro 5
#                  5       livro 6
#                  6       livro 7
#                  7       livro 8
#                  8       livro 9
#                  9      livro 10

# %% [markdown]
# ### 7) Faça a junção das bases de dados livros e livros_classicos e verifique a integridade do dataframe resultante

# %%
pd.concat([livros,livros_classicos], axis = 1, verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7077/2584332982.py in <module>
# ----> 1 pd.concat([livros,livros_classicos], axis = 1, verify_integrity=True)
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     540         self.copy = copy
#     541
# --> 542         self.new_axes = self._get_new_axes()
#     543
#     544     def get_result(self):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     610     def _get_new_axes(self) -> list[Index]:
#     611         ndim = self._get_result_dim()
# --> 612         return [
#     613             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     614             for i in range(ndim)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     611         ndim = self._get_result_dim()
#     612         return [
# --> 613             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     614             for i in range(ndim)
#     615         ]
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     672             )
#     673
# --> 674         self._maybe_check_integrity(concat_axis)
#     675
#     676         return concat_axis
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py in _maybe_check_integrity(self, concat_index)
#     680             if not concat_index.is_unique:
#     681                 overlap = concat_index[concat_index.duplicated()].unique()
# --> 682                 raise ValueError(f"Indexes have overlapping values: {overlap}")
#     683
#     684
#
# ValueError: Indexes have overlapping values: Index(['nome'], dtype='object')
